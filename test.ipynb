# %%
# !python3 TRON-ICE/main.py --service fixedfloat --year 2025
# Out:
# Traceback (most recent call last):
#   File "/content/TRON-ICE/main.py", line 8, in <module>
#     scaping_trongrid()
#   File "/content/TRON-ICE/src/data_collection/scraper_trongrid.py", line 55, in scaping_trongrid
#     URL=URL_TRX.replace("_RELATED_ADDRESS_", HOT_WALLETS[service]),
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: replace() argument 2 must be str, not None
